# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
import scipy.interpolate as spi
import math
import matplotlib.figure as fig
from scipy import stats

# %%
def get_values(array):
    prom = array.mean()
    sum = 0
    for i in array:
        sum += (i-prom)**2
    ret = math.sqrt(sum)
    return prom, ret

# %%
def get_values_list(array, sum):
    prom = sum/len(array)
    sum = 0
    for i in array:
        sum += (i-prom)**2
    ret = math.sqrt(sum)
    return prom, ret

# %%
_2D_c_15_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_15.csv")
_2D_c_25_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_25.csv")
_2D_c_40_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_40.csv")
_2D_c_55_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_55.csv")
_2D_c_65_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_65.csv")
_2D_c_75_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_75.csv")

_2D_c_15_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_c_15.csv")
_2D_c_25_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_c_25.csv")
_2D_c_40_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_c_40.csv")
_2D_c_55_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_c_55.csv")
_2D_c_65_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_c_65.csv")
_2D_c_75_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_c_75.csv")

_2D_c_15_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_c_15.csv")
_2D_c_25_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_c_25.csv")
_2D_c_40_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_c_40.csv")
_2D_c_55_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_c_55.csv")
_2D_c_65_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_c_65.csv")
_2D_c_75_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_c_75.csv")

# %%
plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_c_15_1['I'], _2D_c_15_1['N'])
plt.plot(_2D_c_25_1['I'], _2D_c_25_1['N'])
plt.plot(_2D_c_40_1['I'], _2D_c_40_1['N'])
plt.plot(_2D_c_55_1['I'], _2D_c_55_1['N'])
plt.plot(_2D_c_65_1['I'], _2D_c_65_1['N'])
plt.plot(_2D_c_75_1['I'], _2D_c_75_1['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])
plt.show()

# plt.xlabel('Iteraciones')
# plt.ylabel('Celdas vivas')
# plt.plot(_2D_c_15_2['I'], _2D_c_15_2['N'])
# plt.plot(_2D_c_25_2['I'], _2D_c_25_2['N'])
# plt.plot(_2D_c_40_2['I'], _2D_c_40_2['N'])
# plt.plot(_2D_c_55_2['I'], _2D_c_55_2['N'])
# plt.plot(_2D_c_65_2['I'], _2D_c_65_2['N'])
# plt.plot(_2D_c_75_2['I'], _2D_c_75_2['N'])
# plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])
# plt.show()

# plt.xlabel('Iteraciones')
# plt.ylabel('Celdas vivas')
# plt.plot(_2D_c_15_3['I'], _2D_c_15_3['N'])
# plt.plot(_2D_c_25_3['I'], _2D_c_25_3['N'])
# plt.plot(_2D_c_40_3['I'], _2D_c_40_3['N'])
# plt.plot(_2D_c_55_3['I'], _2D_c_55_3['N'])
# plt.plot(_2D_c_65_3['I'], _2D_c_65_3['N'])
# plt.plot(_2D_c_75_3['I'], _2D_c_75_3['N'])
# plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])

# %%
def tiempo_en_llegar_al_equilibrio(array):
    array_celdas_vivas = array['N'].to_list()
    for i in range(2, len(array_celdas_vivas)):
        if array_celdas_vivas[i] == array_celdas_vivas[i-2]:
            return i
    return 12345

# %%
# subset_1 = _2D_c_15_1.iloc[75:-1]
# subset_2 = _2D_c_25_1.iloc[75:-1]
# subset_3 = _2D_c_40_1.iloc[75:-1]
# subset_4 = _2D_c_55_1.iloc[75:-1]
# subset_5 = _2D_c_65_1.iloc[75:-1]
# subset_6 = _2D_c_75_1.iloc[75:-1]

# p1, d1 = get_values(subset_1['N'])
# p2, d2 = get_values(subset_2['N'])
# p3, d3 = get_values(subset_3['N'])
# p4, d4 = get_values(subset_4['N'])
# p5, d5 = get_values(subset_5['N'])
# p6, d6 = get_values(subset_6['N'])

p11 = tiempo_en_llegar_al_equilibrio(_2D_c_15_1)
p21 = tiempo_en_llegar_al_equilibrio(_2D_c_25_1)
p31 = tiempo_en_llegar_al_equilibrio(_2D_c_40_1)
p41 = tiempo_en_llegar_al_equilibrio(_2D_c_55_1)
p51 = tiempo_en_llegar_al_equilibrio(_2D_c_65_1)
p61 = tiempo_en_llegar_al_equilibrio(_2D_c_75_1)

# subset2_1 = _2D_c_15_2.iloc[75:-1]
# subset2_2 = _2D_c_25_2.iloc[75:-1]
# subset2_3 = _2D_c_40_2.iloc[75:-1]
# subset2_4 = _2D_c_55_2.iloc[75:-1]
# subset2_5 = _2D_c_65_2.iloc[75:-1]
# subset2_6 = _2D_c_75_2.iloc[75:-1]

# p12, d12 = get_values(subset2_1['N'])
# p22, d22 = get_values(subset2_2['N'])
# p32, d32 = get_values(subset2_3['N'])
# p42, d42 = get_values(subset2_4['N'])
# p52, d52 = get_values(subset2_5['N'])
# p62, d62 = get_values(subset2_6['N'])

p12 = tiempo_en_llegar_al_equilibrio(_2D_c_15_2)
p22 = tiempo_en_llegar_al_equilibrio(_2D_c_25_2)
p32 = tiempo_en_llegar_al_equilibrio(_2D_c_40_2)
p42 = tiempo_en_llegar_al_equilibrio(_2D_c_55_2)
p52 = tiempo_en_llegar_al_equilibrio(_2D_c_65_2)
p62 = tiempo_en_llegar_al_equilibrio(_2D_c_75_2)

# subset3_1 = _2D_c_15_3.iloc[75:-1]
# subset3_2 = _2D_c_25_3.iloc[75:-1]
# subset3_3 = _2D_c_40_3.iloc[75:-1]
# subset3_4 = _2D_c_55_3.iloc[75:-1]
# subset3_5 = _2D_c_65_3.iloc[75:-1]
# subset3_6 = _2D_c_75_3.iloc[75:-1]

# p13, d13 = get_values(subset3_1['N'])
# p23, d23 = get_values(subset3_2['N'])
# p33, d33 = get_values(subset3_3['N'])
# p43, d43 = get_values(subset3_4['N'])
# p53, d53 = get_values(subset3_5['N'])
# p63, d63 = get_values(subset3_6['N'])

p13 = tiempo_en_llegar_al_equilibrio(_2D_c_15_3)
p23 = tiempo_en_llegar_al_equilibrio(_2D_c_25_3)
p33 = tiempo_en_llegar_al_equilibrio(_2D_c_40_3)
p43 = tiempo_en_llegar_al_equilibrio(_2D_c_55_3)
p53 = tiempo_en_llegar_al_equilibrio(_2D_c_65_3)
p63 = tiempo_en_llegar_al_equilibrio(_2D_c_75_3)

array1 = [p11, p12, p13]
array2 = [p21, p22, p23]
array3 = [p31, p32, p33]
array4 = [p41, p42, p43]
array5 = [p51, p52, p53]
array6 = [p61, p62, p63]
# print(array1)

cp1,ds1 = get_values_list(array1, sum(array1))
cp2,ds2 = get_values_list(array2, sum(array2))
cp3,ds3 = get_values_list(array3, sum(array3))
cp4,ds4 = get_values_list(array4, sum(array4))
cp5,ds5 = get_values_list(array5, sum(array5))
cp6,ds6 = get_values_list(array6, sum(array6))

array_x = ["15", "25", "40", "55", "65", "75"]
array_y = [cp1, cp2, cp3, cp4, cp5, cp6]
y_errs = [ds1, ds2, ds3, ds4, ds5, ds6]

# plt.figure(figsize=(7,5))
# plt.subplots()
plt.xlabel("Life Expectancy (%)")
plt.ylabel("Observable #3")
plt.errorbar(np.array(array_x), np.array(array_y), yerr=np.array(y_errs), capsize=4, color="orangered", ecolor="steelblue")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
_2D_b_15_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_15.csv")
_2D_b_25_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_25.csv")
_2D_b_40_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_40.csv")
_2D_b_55_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_55.csv")
_2D_b_65_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_65.csv")
_2D_b_75_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_75.csv")

_2D_b_15_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_b_15.csv")
_2D_b_25_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_b_25.csv")
_2D_b_40_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_b_40.csv")
_2D_b_55_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_b_55.csv")
_2D_b_65_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_b_65.csv")
_2D_b_75_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_b_75.csv")

_2D_b_15_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_b_15.csv")
_2D_b_25_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_b_25.csv")
_2D_b_40_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_b_40.csv")
_2D_b_55_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_b_55.csv")
_2D_b_65_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_b_65.csv")
_2D_b_75_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_b_75.csv")

# %%
plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_b_15_1['I'], _2D_b_15_1['N'])
plt.plot(_2D_b_25_1['I'], _2D_b_25_1['N'])
plt.plot(_2D_b_40_1['I'], _2D_b_40_1['N'])
plt.plot(_2D_b_55_1['I'], _2D_b_55_1['N'])
plt.plot(_2D_b_65_1['I'], _2D_b_65_1['N'])
plt.plot(_2D_b_75_1['I'], _2D_b_75_1['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])
plt.show()

# plt.xlabel('Iteraciones')
# plt.ylabel('Celdas vivas')
# plt.plot(_2D_b_15_2['I'], _2D_b_15_2['N'])
# plt.plot(_2D_b_25_2['I'], _2D_b_25_2['N'])
# plt.plot(_2D_b_40_2['I'], _2D_b_40_2['N'])
# plt.plot(_2D_b_55_2['I'], _2D_b_55_2['N'])
# plt.plot(_2D_b_65_2['I'], _2D_b_65_2['N'])
# plt.plot(_2D_b_75_2['I'], _2D_b_75_2['N'])
# plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])
# plt.show()

# plt.xlabel('Iteraciones')
# plt.ylabel('Celdas vivas')
# plt.plot(_2D_b_15_3['I'], _2D_b_15_3['N'])
# plt.plot(_2D_b_25_3['I'], _2D_b_25_3['N'])
# plt.plot(_2D_b_40_3['I'], _2D_b_40_3['N'])
# plt.plot(_2D_b_55_3['I'], _2D_b_55_3['N'])
# plt.plot(_2D_b_65_3['I'], _2D_b_65_3['N'])
# plt.plot(_2D_b_75_3['I'], _2D_b_75_3['N'])
# plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])

# %%
def get_m(array):
    array_x = array['I'].to_list()
    array_y = array['N'].to_list()
    m = (array_y[-1] - array_y[0])/(array_x[-1] - array_x[0])
    return m

def get_tasa_de_crecimiento_cada_10_iteraciones(array):
    array_celdas_vivas = array['N'].to_list()
    array_de_incrementos = []
    for i in range(10, len(array_celdas_vivas), 10):
        array_de_incrementos.append(array_celdas_vivas[i] - array_celdas_vivas[i-10])
    return np.array(array_de_incrementos).mean()

# %%
subset_1 = _2D_b_15_1.iloc[25:-1]
subset_2 = _2D_b_25_1.iloc[25:-1]
subset_3 = _2D_b_40_1.iloc[25:-1]
subset_4 = _2D_b_55_1.iloc[25:-1]
subset_5 = _2D_b_65_1.iloc[25:-1]
subset_6 = _2D_b_75_1.iloc[25:-1]

m1 = get_m(subset_1)
m2 = get_m(subset_2)
m3 = get_m(subset_3)
m4 = get_m(subset_4)
m5 = get_m(subset_5)
m6 = get_m(subset_6)

subset2_1 = _2D_b_15_2.iloc[25:-1]
subset2_2 = _2D_b_25_2.iloc[25:-1]
subset2_3 = _2D_b_40_2.iloc[25:-1]
subset2_4 = _2D_b_55_2.iloc[25:-1]
subset2_5 = _2D_b_65_2.iloc[25:-1]
subset2_6 = _2D_b_75_2.iloc[25:-1]

m12 = get_m(subset2_1)
m22 = get_m(subset2_2)
m32 = get_m(subset2_3)
m42 = get_m(subset2_4)
m52 = get_m(subset2_5)
m62 = get_m(subset2_6)

subset3_1 = _2D_b_15_3.iloc[25:-1]
subset3_2 = _2D_b_25_3.iloc[25:-1]
subset3_3 = _2D_b_40_3.iloc[25:-1]
subset3_4 = _2D_b_55_3.iloc[25:-1]
subset3_5 = _2D_b_65_3.iloc[25:-1]
subset3_6 = _2D_b_75_3.iloc[25:-1]

m13 = get_m(subset3_1)
m23 = get_m(subset3_2)
m33 = get_m(subset3_3)
m43 = get_m(subset3_4)
m53 = get_m(subset3_5)
m63 = get_m(subset3_6)

array1 = [m1, m12, m13]
array2 = [m2, m22, m23]
array3 = [m3, m32, m33]
array4 = [m4, m42, m43]
array5 = [m5, m52, m53]
array6 = [m6, m62, m63]
# print(array1)
# print(array2)
# print(array3)
# print(array4)
# print(array5)
# print(array6)

cp1,ds1 = get_values_list(array1, sum(array1))
cp2,ds2 = get_values_list(array2, sum(array2))
cp3,ds3 = get_values_list(array3, sum(array3))
cp4,ds4 = get_values_list(array4, sum(array4))
cp5,ds5 = get_values_list(array5, sum(array5))
cp6,ds6 = get_values_list(array6, sum(array6))

array_x = ["15", "25", "40", "55", "65", "75"]
array_y = [cp1, cp2, cp3, cp4, cp5, cp6]
y_errs = [ds1, ds2, ds3, ds4, ds5, ds6]

# plt.figure(figsize=(7,5))
# plt.subplots()
plt.xlabel("Life Expectancy (%)")
plt.ylabel("Observable #2")
plt.errorbar(np.array(array_x), np.array(array_y), yerr=np.array(y_errs), capsize=4, color="orangered", ecolor="steelblue")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
_2D_a_15_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_15.csv")
_2D_a_25_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_25.csv")
_2D_a_40_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_40.csv")
_2D_a_55_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_55.csv")
_2D_a_65_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_65.csv")
_2D_a_75_1 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_75.csv")

_2D_a_15_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_a_15.csv")
_2D_a_25_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_a_25.csv")
_2D_a_40_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_a_40.csv")
_2D_a_55_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_a_55.csv")
_2D_a_65_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_a_65.csv")
_2D_a_75_2 = pd.read_csv("../PythonFiles2/outputForPython2_2D_a_75.csv")

_2D_a_15_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_a_15.csv")
_2D_a_25_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_a_25.csv")
_2D_a_40_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_a_40.csv")
_2D_a_55_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_a_55.csv")
_2D_a_65_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_a_65.csv")
_2D_a_75_3 = pd.read_csv("../PythonFiles3/outputForPython2_2D_a_75.csv")

# %%
plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_a_15_1['I'], _2D_a_15_1['N'])
plt.plot(_2D_a_25_1['I'], _2D_a_25_1['N'])
plt.plot(_2D_a_40_1['I'], _2D_a_40_1['N'])
plt.plot(_2D_a_55_1['I'], _2D_a_55_1['N'])
plt.plot(_2D_a_65_1['I'], _2D_a_65_1['N'])
plt.plot(_2D_a_75_1['I'], _2D_a_75_1['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])
plt.show()

# plt.xlabel('Iteraciones')
# plt.ylabel('Celdas vivas')
# plt.plot(_2D_a_15_2['I'], _2D_a_15_2['N'])
# plt.plot(_2D_a_25_2['I'], _2D_a_25_2['N'])
# plt.plot(_2D_a_40_2['I'], _2D_a_40_2['N'])
# plt.plot(_2D_a_55_2['I'], _2D_a_55_2['N'])
# plt.plot(_2D_a_65_2['I'], _2D_a_65_2['N'])
# plt.plot(_2D_a_75_2['I'], _2D_a_75_2['N'])
# plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])
# plt.show()

# plt.xlabel('Iteraciones')
# plt.ylabel('Celdas vivas')
# plt.plot(_2D_a_15_3['I'], _2D_a_15_3['N'])
# plt.plot(_2D_a_25_3['I'], _2D_a_25_3['N'])
# plt.plot(_2D_a_40_3['I'], _2D_a_40_3['N'])
# plt.plot(_2D_a_55_3['I'], _2D_a_55_3['N'])
# plt.plot(_2D_a_65_3['I'], _2D_a_65_3['N'])
# plt.plot(_2D_a_75_3['I'], _2D_a_75_3['N'])
# plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 55', 'LE = 65', 'LE = 75',])

# %%
subset_1 = _2D_a_15_1.iloc[75:-1]
subset_2 = _2D_a_25_1.iloc[75:-1]
subset_3 = _2D_a_40_1.iloc[75:-1]
subset_4 = _2D_a_55_1.iloc[75:-1]
subset_5 = _2D_a_65_1.iloc[75:-1]
subset_6 = _2D_a_75_1.iloc[75:-1]

p1, d1 = get_values(subset_1['N'])
p2, d2 = get_values(subset_2['N'])
p3, d3 = get_values(subset_3['N'])
p4, d4 = get_values(subset_4['N'])
p5, d5 = get_values(subset_5['N'])
p6, d6 = get_values(subset_6['N'])

subset2_1 = _2D_a_15_2.iloc[75:-1]
subset2_2 = _2D_a_25_2.iloc[75:-1]
subset2_3 = _2D_a_40_2.iloc[75:-1]
subset2_4 = _2D_a_55_2.iloc[75:-1]
subset2_5 = _2D_a_65_2.iloc[75:-1]
subset2_6 = _2D_a_75_2.iloc[75:-1]

p12, d12 = get_values(subset2_1['N'])
p22, d22 = get_values(subset2_2['N'])
p32, d32 = get_values(subset2_3['N'])
p42, d42 = get_values(subset2_4['N'])
p52, d52 = get_values(subset2_5['N'])
p62, d62 = get_values(subset2_6['N'])

subset3_1 = _2D_a_15_3.iloc[75:-1]
subset3_2 = _2D_a_25_3.iloc[75:-1]
subset3_3 = _2D_a_40_3.iloc[75:-1]
subset3_4 = _2D_a_55_3.iloc[75:-1]
subset3_5 = _2D_a_65_3.iloc[75:-1]
subset3_6 = _2D_a_75_3.iloc[75:-1]

p13, d13 = get_values(subset3_1['N'])
p23, d23 = get_values(subset3_2['N'])
p33, d33 = get_values(subset3_3['N'])
p43, d43 = get_values(subset3_4['N'])
p53, d53 = get_values(subset3_5['N'])
p63, d63 = get_values(subset3_6['N'])

array1 = [p1, p12, p13]
array2 = [p2, p22, p23]
array3 = [p3, p32, p33]
array4 = [p4, p42, p43]
array5 = [p5, p52, p53]
array6 = [p6, p62, p63]
print(array1)

cp1,ds1 = get_values_list(array1, sum(array1))
cp2,ds2 = get_values_list(array2, sum(array2))
cp3,ds3 = get_values_list(array3, sum(array3))
cp4,ds4 = get_values_list(array4, sum(array4))
cp5,ds5 = get_values_list(array5, sum(array5))
cp6,ds6 = get_values_list(array6, sum(array6))

array_x = ["15", "25", "40", "55", "65", "75"]
array_y = [cp1, cp2, cp3, cp4, cp5, cp6]
y_errs = [ds1, ds2, ds3, ds4, ds5, ds6]

# plt.figure(figsize=(7,5))
# plt.subplots()
plt.xlabel("Life Expectancy (%)")
plt.ylabel("Observable #1")
plt.errorbar(np.array(array_x), np.array(array_y), yerr=np.array(y_errs), capsize=4, color="orangered", ecolor="steelblue")
# Out:
# [2834.968, 3468.336, 3169.376]
# <ErrorbarContainer object of 3 artists>
