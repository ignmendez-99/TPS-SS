# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
import scipy.interpolate as spi
import math
import matplotlib.figure as fig
from scipy import stats

# %%
_2D_a_15 = pd.read_csv("../PythonFiles/outputForPython2_2D_a_15.csv")
_2D_a_25 = pd.read_csv("../PythonFiles/outputForPython2_2D_a_25.csv")
_2D_a_40 = pd.read_csv("../PythonFiles/outputForPython2_2D_a_40.csv")
_2D_a_60 = pd.read_csv("../PythonFiles/outputForPython2_2D_a_60.csv")
_2D_a_80 = pd.read_csv("../PythonFiles/outputForPython2_2D_a_80.csv")
_2D_a_100 = pd.read_csv("../PythonFiles/outputForPython2_2D_a_100.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_a_15['I'], _2D_a_15['N'])
plt.plot(_2D_a_25['I'], _2D_a_25['N'])
plt.plot(_2D_a_40['I'], _2D_a_40['N'])
plt.plot(_2D_a_60['I'], _2D_a_60['N'])
plt.plot(_2D_a_80['I'], _2D_a_80['N'])
plt.plot(_2D_a_100['I'], _2D_a_100['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_2D_a_15['I'], _2D_a_15['R'])
plt.plot(_2D_a_25['I'], _2D_a_25['R'])
plt.plot(_2D_a_40['I'], _2D_a_40['R'])
plt.plot(_2D_a_60['I'], _2D_a_60['R'])
plt.plot(_2D_a_80['I'], _2D_a_80['R'])
plt.plot(_2D_a_100['I'], _2D_a_100['R'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])

# %%
_2D_b_15 = pd.read_csv("../PythonFiles/outputForPython2_2D_b_15.csv")
_2D_b_25 = pd.read_csv("../PythonFiles/outputForPython2_2D_b_25.csv")
_2D_b_40 = pd.read_csv("../PythonFiles/outputForPython2_2D_b_40.csv")
_2D_b_60 = pd.read_csv("../PythonFiles/outputForPython2_2D_b_60.csv")
_2D_b_80 = pd.read_csv("../PythonFiles/outputForPython2_2D_b_80.csv")
_2D_b_100 = pd.read_csv("../PythonFiles/outputForPython2_2D_b_100.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_b_15['I'], _2D_b_15['N'])
plt.plot(_2D_b_25['I'], _2D_b_25['N'])
plt.plot(_2D_b_40['I'], _2D_b_40['N'])
plt.plot(_2D_b_60['I'], _2D_b_60['N'])
plt.plot(_2D_b_80['I'], _2D_b_80['N'])
plt.plot(_2D_b_100['I'], _2D_b_100['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_2D_b_15['I'], _2D_b_15['R'])
plt.plot(_2D_b_25['I'], _2D_b_25['R'])
plt.plot(_2D_b_40['I'], _2D_b_40['R'])
plt.plot(_2D_b_60['I'], _2D_b_60['R'])
plt.plot(_2D_b_80['I'], _2D_b_80['R'])
plt.plot(_2D_b_100['I'], _2D_b_100['R'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])

# %%
_2D_c_15 = pd.read_csv("../PythonFiles/outputForPython2_2D_c_15.csv")
_2D_c_25 = pd.read_csv("../PythonFiles/outputForPython2_2D_c_25.csv")
_2D_c_40 = pd.read_csv("../PythonFiles/outputForPython2_2D_c_40.csv")
_2D_c_60 = pd.read_csv("../PythonFiles/outputForPython2_2D_c_60.csv")
_2D_c_80 = pd.read_csv("../PythonFiles/outputForPython2_2D_c_80.csv")
_2D_c_100 = pd.read_csv("../PythonFiles/outputForPython2_2D_c_100.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_c_15['I'], _2D_c_15['N'])
plt.plot(_2D_c_25['I'], _2D_c_25['N'])
plt.plot(_2D_c_40['I'], _2D_c_40['N'])
plt.plot(_2D_c_60['I'], _2D_c_60['N'])
plt.plot(_2D_c_80['I'], _2D_c_80['N'])
plt.plot(_2D_c_100['I'], _2D_c_100['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_2D_c_15['I'], _2D_c_15['R'])
plt.plot(_2D_c_25['I'], _2D_c_25['R'])
plt.plot(_2D_c_40['I'], _2D_c_40['R'])
plt.plot(_2D_c_60['I'], _2D_c_60['R'])
plt.plot(_2D_c_80['I'], _2D_c_80['R'])
plt.plot(_2D_c_100['I'], _2D_c_100['R'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])

# %%
_3D_a_15 = pd.read_csv("../PythonFiles/outputForPython2_3D_a_15.csv")
_3D_a_25 = pd.read_csv("../PythonFiles/outputForPython2_3D_a_25.csv")
_3D_a_40 = pd.read_csv("../PythonFiles/outputForPython2_3D_a_40.csv")
_3D_a_60 = pd.read_csv("../PythonFiles/outputForPython2_3D_a_60.csv")
_3D_a_80 = pd.read_csv("../PythonFiles/outputForPython2_3D_a_80.csv")
_3D_a_100 = pd.read_csv("../PythonFiles/outputForPython2_3D_a_100.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_3D_a_15['I'], _3D_a_15['N'])
plt.plot(_3D_a_25['I'], _3D_a_25['N'])
plt.plot(_3D_a_40['I'], _3D_a_40['N'])
plt.plot(_3D_a_60['I'], _3D_a_60['N'])
plt.plot(_3D_a_80['I'], _3D_a_80['N'])
plt.plot(_3D_a_100['I'], _3D_a_100['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_3D_a_15['I'], _3D_a_15['R'])
plt.plot(_3D_a_25['I'], _3D_a_25['R'])
plt.plot(_3D_a_40['I'], _3D_a_40['R'])
plt.plot(_3D_a_60['I'], _3D_a_60['R'])
plt.plot(_3D_a_80['I'], _3D_a_80['R'])
plt.plot(_3D_a_100['I'], _3D_a_100['R'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])

# %%
_3D_b_15 = pd.read_csv("../PythonFiles/outputForPython2_3D_b_15.csv")
_3D_b_25 = pd.read_csv("../PythonFiles/outputForPython2_3D_b_25.csv")
_3D_b_40 = pd.read_csv("../PythonFiles/outputForPython2_3D_b_40.csv")
_3D_b_60 = pd.read_csv("../PythonFiles/outputForPython2_3D_b_60.csv")
_3D_b_80 = pd.read_csv("../PythonFiles/outputForPython2_3D_b_80.csv")
_3D_b_100 = pd.read_csv("../PythonFiles/outputForPython2_3D_b_100.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_3D_b_15['I'], _3D_b_15['N'])
plt.plot(_3D_b_25['I'], _3D_b_25['N'])
plt.plot(_3D_b_40['I'], _3D_b_40['N'])
plt.plot(_3D_b_60['I'], _3D_b_60['N'])
plt.plot(_3D_b_80['I'], _3D_b_80['N'])
plt.plot(_3D_b_100['I'], _3D_b_100['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_3D_b_15['I'], _3D_b_15['R'])
plt.plot(_3D_b_25['I'], _3D_b_25['R'])
plt.plot(_3D_b_40['I'], _3D_b_40['R'])
plt.plot(_3D_b_60['I'], _3D_b_60['R'])
plt.plot(_3D_b_80['I'], _3D_b_80['R'])
plt.plot(_3D_b_100['I'], _3D_b_100['R'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])

# %%
_3D_c_15 = pd.read_csv("../PythonFiles/outputForPython2_3D_c_15.csv")
_3D_c_25 = pd.read_csv("../PythonFiles/outputForPython2_3D_c_25.csv")
_3D_c_40 = pd.read_csv("../PythonFiles/outputForPython2_3D_c_40.csv")
_3D_c_60 = pd.read_csv("../PythonFiles/outputForPython2_3D_c_60.csv")
_3D_c_80 = pd.read_csv("../PythonFiles/outputForPython2_3D_c_80.csv")
_3D_c_100 = pd.read_csv("../PythonFiles/outputForPython2_3D_c_100.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_3D_c_15['I'], _3D_c_15['N'])
plt.plot(_3D_c_25['I'], _3D_c_25['N'])
plt.plot(_3D_c_40['I'], _3D_c_40['N'])
plt.plot(_3D_c_60['I'], _3D_c_60['N'])
plt.plot(_3D_c_80['I'], _3D_c_80['N'])
plt.plot(_3D_c_100['I'], _3D_c_100['N'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_3D_c_15['I'], _3D_c_15['R'])
plt.plot(_3D_c_25['I'], _3D_c_25['R'])
plt.plot(_3D_c_40['I'], _3D_c_40['R'])
plt.plot(_3D_c_60['I'], _3D_c_60['R'])
plt.plot(_3D_c_80['I'], _3D_c_80['R'])
plt.plot(_3D_c_100['I'], _3D_c_100['R'])
plt.legend(['LE = 15', 'LE = 25', 'LE = 40', 'LE = 60', 'LE = 80', 'LE = 100',])
