# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
import scipy.interpolate as spi
import math
import matplotlib.figure as fig
from scipy import stats

# %%
def split(array_t,value):
    i = 0
    for it in array_t:
        if it > value:
            return i
        i += 1

# %%
def get_values(array):
    prom = array.mean()
    sum = 0
    for i in array:
        sum += (i-prom)**2
    ret = math.sqrt(sum)
    return prom, ret

# %%
_2D_a_15 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_15.csv")
_2D_a_25 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_25.csv")
_2D_a_40 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_40.csv")
_2D_a_55 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_55.csv")
_2D_a_65 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_65.csv")
_2D_a_75 = pd.read_csv("../PythonFiles1/outputForPython2_2D_a_75.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_a_15['I'], _2D_a_15['N'])
plt.plot(_2D_a_25['I'], _2D_a_25['N'])
plt.plot(_2D_a_40['I'], _2D_a_40['N'])
plt.plot(_2D_a_55['I'], _2D_a_55['N'])
plt.plot(_2D_a_65['I'], _2D_a_65['N'])
plt.plot(_2D_a_75['I'], _2D_a_75['N'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_2D_a_15['I'], _2D_a_15['R'])
plt.plot(_2D_a_25['I'], _2D_a_25['R'])
plt.plot(_2D_a_40['I'], _2D_a_40['R'])
plt.plot(_2D_a_55['I'], _2D_a_55['R'])
plt.plot(_2D_a_65['I'], _2D_a_65['R'])
plt.plot(_2D_a_75['I'], _2D_a_75['R'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()


# subset_1 = _2D_a_15.iloc[75:-1]
# subset_2 = _2D_a_25.iloc[75:-1]
# subset_3 = _2D_a_40.iloc[75:-1]
# subset_4 = _2D_a_55.iloc[75:-1]
# subset_5 = _2D_a_65.iloc[75:-1]
# subset_6 = _2D_a_75.iloc[75:-1]

# p1, d1 = get_values(subset_1['N'])
# p2, d2 = get_values(subset_2['N'])
# p3, d3 = get_values(subset_3['N'])
# p4, d4 = get_values(subset_4['N'])
# p5, d5 = get_values(subset_5['N'])
# p6, d6 = get_values(subset_6['N'])

# array_x = ["15", "25", "40", "55", "65", "75"]
# array_y = [p1, p2, p3, p4, p5, p6]
# y_errs = [d1, d2, d3, d4, d5, d6]

# # plt.figure(figsize=(7,5))
# # plt.subplots()
# plt.xlabel('Input')
# plt.ylabel('Observable')
# plt.errorbar(np.array(array_x), np.array(array_y), yerr=np.array(y_errs)/2, capsize=4, color="orangered", ecolor="steelblue")

# %%
_2D_b_15 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_15.csv")
_2D_b_25 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_25.csv")
_2D_b_40 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_40.csv")
_2D_b_55 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_55.csv")
_2D_b_65 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_65.csv")
_2D_b_75 = pd.read_csv("../PythonFiles1/outputForPython2_2D_b_75.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_b_15['I'], _2D_b_15['N'])
plt.plot(_2D_b_25['I'], _2D_b_25['N'])
plt.plot(_2D_b_40['I'], _2D_b_40['N'])
plt.plot(_2D_b_55['I'], _2D_b_55['N'])
plt.plot(_2D_b_65['I'], _2D_b_65['N'])
plt.plot(_2D_b_75['I'], _2D_b_75['N'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_2D_b_15['I'], _2D_b_15['R'])
plt.plot(_2D_b_25['I'], _2D_b_25['R'])
plt.plot(_2D_b_40['I'], _2D_b_40['R'])
plt.plot(_2D_b_55['I'], _2D_b_55['R'])
plt.plot(_2D_b_65['I'], _2D_b_65['R'])
plt.plot(_2D_b_75['I'], _2D_b_75['R'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])

# %%
_2D_c_15 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_15.csv")
_2D_c_25 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_25.csv")
_2D_c_40 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_40.csv")
_2D_c_55 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_55.csv")
_2D_c_65 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_65.csv")
_2D_c_75 = pd.read_csv("../PythonFiles1/outputForPython2_2D_c_75.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_2D_c_15['I'], _2D_c_15['N'])
plt.plot(_2D_c_25['I'], _2D_c_25['N'])
plt.plot(_2D_c_40['I'], _2D_c_40['N'])
plt.plot(_2D_c_55['I'], _2D_c_55['N'])
plt.plot(_2D_c_65['I'], _2D_c_65['N'])
plt.plot(_2D_c_75['I'], _2D_c_75['N'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_2D_c_15['I'], _2D_c_15['R'])
plt.plot(_2D_c_25['I'], _2D_c_25['R'])
plt.plot(_2D_c_40['I'], _2D_c_40['R'])
plt.plot(_2D_c_55['I'], _2D_c_55['R'])
plt.plot(_2D_c_65['I'], _2D_c_65['R'])
plt.plot(_2D_c_75['I'], _2D_c_75['R'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()

# subset_1 = _2D_c_15.iloc[50:-1]
# subset_2 = _2D_c_25.iloc[50:-1]
# subset_3 = _2D_c_40.iloc[50:-1]
# subset_4 = _2D_c_55.iloc[50:-1]
# subset_5 = _2D_c_65.iloc[50:-1]
# subset_6 = _2D_c_75.iloc[50:-1]

# p1, d1 = get_values(subset_1['N'])
# p2, d2 = get_values(subset_2['N'])
# p3, d3 = get_values(subset_3['N'])
# p4, d4 = get_values(subset_4['N'])
# p5, d5 = get_values(subset_5['N'])
# p6, d6 = get_values(subset_6['N'])

# array_x = ["15", "25", "40", "55", "65", "75"]
# array_y = [p1, p2, p3, p4, p5, p6]
# y_errs = [d1, d2, d3, d4, d5, d6]

# # plt.figure(figsize=(7,5))
# # plt.subplots()
# plt.xlabel('Input')
# plt.ylabel('Observable')
# plt.errorbar(np.array(array_x), np.array(array_y), yerr=np.array(y_errs)/2, capsize=4, color="orangered", ecolor="steelblue")

# %%
_3D_a_15 = pd.read_csv("../PythonFiles1/outputForPython2_3D_a_15.csv")
_3D_a_25 = pd.read_csv("../PythonFiles1/outputForPython2_3D_a_25.csv")
_3D_a_40 = pd.read_csv("../PythonFiles1/outputForPython2_3D_a_40.csv")
_3D_a_55 = pd.read_csv("../PythonFiles1/outputForPython2_3D_a_55.csv")
_3D_a_65 = pd.read_csv("../PythonFiles1/outputForPython2_3D_a_65.csv")
_3D_a_75 = pd.read_csv("../PythonFiles1/outputForPython2_3D_a_75.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_3D_a_15['I'], _3D_a_15['N'])
plt.plot(_3D_a_25['I'], _3D_a_25['N'])
plt.plot(_3D_a_40['I'], _3D_a_40['N'])
plt.plot(_3D_a_55['I'], _3D_a_55['N'])
plt.plot(_3D_a_65['I'], _3D_a_65['N'])
plt.plot(_3D_a_75['I'], _3D_a_75['N'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_3D_a_15['I'], _3D_a_15['R'])
plt.plot(_3D_a_25['I'], _3D_a_25['R'])
plt.plot(_3D_a_40['I'], _3D_a_40['R'])
plt.plot(_3D_a_55['I'], _3D_a_55['R'])
plt.plot(_3D_a_65['I'], _3D_a_65['R'])
plt.plot(_3D_a_75['I'], _3D_a_75['R'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])

# %%
_3D_b_15 = pd.read_csv("../PythonFiles1/outputForPython2_3D_b_15.csv")
_3D_b_25 = pd.read_csv("../PythonFiles1/outputForPython2_3D_b_25.csv")
_3D_b_40 = pd.read_csv("../PythonFiles1/outputForPython2_3D_b_40.csv")
_3D_b_55 = pd.read_csv("../PythonFiles1/outputForPython2_3D_b_55.csv")
_3D_b_65 = pd.read_csv("../PythonFiles1/outputForPython2_3D_b_65.csv")
_3D_b_75 = pd.read_csv("../PythonFiles1/outputForPython2_3D_b_75.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_3D_b_15['I'], _3D_b_15['N'])
plt.plot(_3D_b_25['I'], _3D_b_25['N'])
plt.plot(_3D_b_40['I'], _3D_b_40['N'])
plt.plot(_3D_b_55['I'], _3D_b_55['N'])
plt.plot(_3D_b_65['I'], _3D_b_65['N'])
plt.plot(_3D_b_75['I'], _3D_b_75['N'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_3D_b_15['I'], _3D_b_15['R'])
plt.plot(_3D_b_25['I'], _3D_b_25['R'])
plt.plot(_3D_b_40['I'], _3D_b_40['R'])
plt.plot(_3D_b_55['I'], _3D_b_55['R'])
plt.plot(_3D_b_65['I'], _3D_b_65['R'])
plt.plot(_3D_b_75['I'], _3D_b_75['R'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()


# subset_1 = _3D_b_15.iloc[75:-1]
# subset_2 = _3D_b_25.iloc[75:-1]
# subset_3 = _3D_b_40.iloc[75:-1]
# subset_4 = _3D_b_55.iloc[75:-1]
# subset_5 = _3D_b_65.iloc[75:-1]
# subset_6 = _3D_b_75.iloc[75:-1]

# p1, d1 = get_values(subset_1['N'])
# p2, d2 = get_values(subset_2['N'])
# p3, d3 = get_values(subset_3['N'])
# p4, d4 = get_values(subset_4['N'])
# p5, d5 = get_values(subset_5['N'])
# p6, d6 = get_values(subset_6['N'])

# array_x = ["15", "25", "40", "55", "65", "75"]
# array_y = [p1, p2, p3, p4, p5, p6]
# y_errs = [d1, d2, d3, d4, d5, d6]

# # plt.figure(figsize=(7,5))
# # plt.subplots()
# plt.xlabel('Input')
# plt.ylabel('Observable')
# plt.errorbar(np.array(array_x), np.array(array_y), yerr=np.array(y_errs)/2, capsize=4, color="orangered", ecolor="steelblue")

# %%
_3D_c_15 = pd.read_csv("../PythonFiles1/outputForPython2_3D_c_15.csv")
_3D_c_25 = pd.read_csv("../PythonFiles1/outputForPython2_3D_c_25.csv")
_3D_c_40 = pd.read_csv("../PythonFiles1/outputForPython2_3D_c_40.csv")
_3D_c_55 = pd.read_csv("../PythonFiles1/outputForPython2_3D_c_55.csv")
_3D_c_65 = pd.read_csv("../PythonFiles1/outputForPython2_3D_c_65.csv")
_3D_c_75 = pd.read_csv("../PythonFiles1/outputForPython2_3D_c_75.csv")

plt.xlabel('Iteraciones')
plt.ylabel('Celdas vivas')
plt.plot(_3D_c_15['I'], _3D_c_15['N'])
plt.plot(_3D_c_25['I'], _3D_c_25['N'])
plt.plot(_3D_c_40['I'], _3D_c_40['N'])
plt.plot(_3D_c_55['I'], _3D_c_55['N'])
plt.plot(_3D_c_65['I'], _3D_c_65['N'])
plt.plot(_3D_c_75['I'], _3D_c_75['N'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
plt.xlabel('Iteraciones')
plt.ylabel('Distancia al centro')
plt.plot(_3D_c_15['I'], _3D_c_15['R'])
plt.plot(_3D_c_25['I'], _3D_c_25['R'])
plt.plot(_3D_c_40['I'], _3D_c_40['R'])
plt.plot(_3D_c_55['I'], _3D_c_55['R'])
plt.plot(_3D_c_65['I'], _3D_c_65['R'])
plt.plot(_3D_c_75['I'], _3D_c_75['R'])
plt.legend(['LE = 15%', 'LE = 25%', 'LE = 40%', 'LE = 55%', 'LE = 65%', 'LE = 75%',])
plt.show()
